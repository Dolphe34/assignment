# %% [markdown]
# My Jupyter Notebook on Watson Studio

# %% [markdown]
# 𝗠𝗼𝘂𝗮𝗱 𝗠𝗼𝗾𝗿𝗮𝗻𝗲
# 𝓼𝓽𝓾𝓭𝓮𝓷𝓽

# %% [markdown]
# 𝘐'𝘮 𝘪𝘯𝘵𝘦𝘳𝘦𝘴𝘵𝘦𝘥 𝘪𝘯 𝘥𝘢𝘵𝘢 𝘣𝘦𝘤𝘢𝘶𝘴𝘦 𝘥𝘢𝘵𝘢 𝘪𝘴 𝘢 𝘷𝘦𝘳𝘺 𝘪𝘮𝘱𝘰𝘳𝘵𝘢𝘯𝘵 𝘦𝘭𝘦𝘮𝘦𝘯𝘵 𝘪𝘯 𝘰𝘶𝘳 𝘥𝘢𝘪𝘭𝘺 𝘭𝘪𝘧𝘦 𝘢𝘴 𝘸𝘦𝘭𝘭 𝘢𝘴 𝘢𝘭𝘭 𝘰𝘳𝘨𝘢𝘯𝘪𝘻𝘢𝘵𝘪𝘰𝘯𝘴' 𝘴 𝘭𝘪𝘧𝘦

# %% [markdown]
# ### getting  an output of 2+2=4

# %%
2+2
# Out:
# 4

# %% [markdown]
# table

# %% [markdown]
# |name| |age| |sex|
# |----| |---| |---|
# |Sara| |25| |F|
# |Alen| |32| |M|
# |Karl| |28| |M|

# %% [markdown]
# Numbered list

# %% [markdown]
# 1. Elephant
# 2. Tiger
# 3. Lion
# 4. Eagle
# 5. Giraffe

# %% [markdown]
# horizontal line

# %% [markdown]
# <hr>

# %% [markdown]
# bullted list

# %% [markdown]
# * a
# * b
# * c
# * d

# %% [markdown]
# image

# %% [markdown]
# ![p5.jpg](attachment:p5.jpg)

# %% [markdown]
# hyperlink

# %% [markdown]
# [how to use Jupyter](https://www.codecademy.com/article/how-to-use-jupyter-notebooks)

# %% [markdown]
# blockquote

# %% [markdown]
# >my assignment
# >>my assignment
# >>>my assignment
